# %%
from efficient_gp.data_utils import load_dataset
from efficient_gp.gp import ONGP, bit_order_to_inv_permutation
from efficient_gp.gp_mixture import GPMixture


import torch
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

import time
import gc

# %%
datasets = [
    "pol",
    "elevators",
    "bike",
    "kin40k",
    "protein",
    "keggdirected",
#     "slice",
    "keggundirected",
    "3droad",
#     "song",
    "buzz",
#     "houseelectric",
]

# %%
from __future__ import annotations

import warnings
from math import ceil
from typing import Dict, List, Optional, Tuple, Union

import torch

from torch import Tensor
from torch.distributions import Normal
from torch.quasirandom import SobolEngine
def initialize_q_batch(X: Tensor, Y: Tensor, n: int, eta: float = 1.0) -> Tensor:
    r"""Heuristic for selecting initial conditions for candidate generation.
    This heuristic selects points from `X` (without replacement) with probability
    proportional to `exp(eta * Z)`, where `Z = (Y - mean(Y)) / std(Y)` and `eta`
    is a temperature parameter.
    When using an acquisiton function that is non-negative and possibly zero
    over large areas of the feature space (e.g. qEI), you should use
    `initialize_q_batch_nonneg` instead.
    Args:
        X: A `b x batch_shape x q x d` tensor of `b` - `batch_shape` samples of
            `q`-batches from a d`-dim feature space. Typically, these are generated
            using qMC sampling.
        Y: A tensor of `b x batch_shape` outcomes associated with the samples.
            Typically, this is the value of the batch acquisition function to be
            maximized.
        n: The number of initial condition to be generated. Must be less than `b`.
        eta: Temperature parameter for weighting samples.
    Returns:
        A `n x batch_shape x q x d` tensor of `n` - `batch_shape` `q`-batch initial
        conditions, where each batch of `n x q x d` samples is selected independently.
    Example:
        >>> # To get `n=10` starting points of q-batch size `q=3`
        >>> # for model with `d=6`:
        >>> qUCB = qUpperConfidenceBound(model, beta=0.1)
        >>> Xrnd = torch.rand(500, 3, 6)
        >>> Xinit = initialize_q_batch(Xrnd, qUCB(Xrnd), 10)
    """
    n_samples = X.shape[0]
    batch_shape = X.shape[1:-2] or torch.Size()
    if n > n_samples:
        raise RuntimeError(
            f"n ({n}) cannot be larger than the number of "
            f"provided samples ({n_samples})"
        )
    elif n == n_samples:
        return X

    Ystd = Y.std(dim=0)
    if torch.any(Ystd == 0):
        warnings.warn(
            "All acquisition values for raw samples points are the same for "
            "at least one batch. Choosing initial conditions at random.",
            RuntimeWarning,
        )
        return X[torch.randperm(n=n_samples, device=X.device)][:n]

    max_val, max_idx = torch.max(Y, dim=0)
    Z = (Y - Y.mean(dim=0)) / Ystd
    etaZ = eta * Z
    weights = torch.exp(etaZ)
    while torch.isinf(weights).any():
        etaZ *= 0.5
        weights = torch.exp(etaZ)
    if batch_shape == torch.Size():
        idcs = torch.multinomial(weights, n)
    else:
        idcs = batched_multinomial(
            weights=weights.permute(*range(1, len(batch_shape) + 1), 0), num_samples=n
        ).permute(-1, *range(len(batch_shape)))
    # make sure we get the maximum
    if max_idx not in idcs:
        idcs[-1] = max_idx
    if batch_shape == torch.Size():
        return X[idcs]
    else:
        return X.gather(
            dim=0, index=idcs.view(*idcs.shape, 1, 1).expand(n, *X.shape[1:])
        )

# %%
def initialize_bit_order(gp, n=20, raw_samples=1000):
    bit_orders_weights = []
    train_nlls = []
    # initialize bit order
    orig_weight = gp.weights[-1].item()
    for _ in range(raw_samples):
        for weight in (orig_weight, 0.5, 0.9):
            gp.weights[-1] = weight
            gp.weights[:-1] = (1-weight)/(gp.weights.shape[0]-1)
            gp.random_bit_order()
    #         gp.random_weights()
            bit_orders_weights.append(torch.cat([gp.bit_order.clone(), gp.weights[-1:].clone().view(1,1).expand(gp.bit_order.shape[0], 1)], dim=-1))
            gp.process()
            train_nlls.append(gp.nll)
    return initialize_q_batch(X=torch.stack(bit_orders_weights, dim=0), Y=-torch.stack(train_nlls), n=n)
#     return bit_orders, train_nlls

# %%
path_start = "../data/uci/"
test_rmses_all = {}
test_nlls_all = {}
train_times_all = {}
predict_times_all = {}
init_times_all = {}
mixture_rmse_all_perf_weighting = {}
mixture_nll_all_perf_weighting = {}
mixture_rmse_all_uniform_weighting = {}
mixture_nll_all_uniform_weighting = {}
all_init_bit_orders = {}
all_final_bit_orders = {}
all_last_bit_weights = {}
SEEDS = [0,1,2]
torch.manual_seed(0)
NUM_RESTARTS = 20
RAW_SAMPLES = 160
n_gps = NUM_RESTARTS

performance_weighting = 100 # maybe sqrt(n data points) is a good anchor?

for name in datasets:
    test_rmses = []
    test_nlls = []
    mixture_rmse_perf_weightings = []
    mixture_nll_perf_weightings = []
    mixture_rmse_uniform_weightings = []
    mixture_nll_uniform_weightings = []
    mixture_init_bit_orders = []
    mixture_last_bit_weights = []
    mixture_final_bit_orders = []
    train_times = []
    predict_times = []
    init_times = []
    torch.manual_seed(0)
    for seed in SEEDS:
        mixture_rmse_perf_weighting = {}
        mixture_nll_perf_weighting = {}
        mixture_rmse_uniform_weighting = {}
        mixture_nll_uniform_weighting = {}
        train_x, train_y, val_x, val_y, test_x, test_y = load_dataset(
            path_start + f"{name}/{name}.mat",
            random_split=seed,
        )
        del val_x, val_y
        LAMBDA = 1/train_x.shape[0]

        test_y = test_y.to(device=device, dtype=torch.float64)
        gp = ONGP(train_x.to(dtype=torch.float64, device=device),
                  train_y.to(dtype=torch.float64, device=device),
                  test_x.to(dtype=torch.float64, device=device), lambd=1e-5, precision="auto")
        # initialize bit order
        init_time = time.time()
        bit_orders = initialize_bit_order(gp, n=NUM_RESTARTS, raw_samples=RAW_SAMPLES)
        mixture_init_bit_orders.append(bit_orders.clone())
        last_bit_weights = bit_orders[:,0, -1]
        bit_orders = bit_orders[:,:, :-1].long()
        
        init_times.append(time.time()-init_time)
        _test_nlls = []
        _test_rmses = []
        _train_nlls = []
        gp_pop = GPMixture(train_x.to(device=device, dtype=torch.float64),
          train_y.to(device=device, dtype=torch.float64),
          test_x.to(device=device, dtype=torch.float64),
          lambd=LAMBDA)
        for i in range(NUM_RESTARTS):
            gp.weights[-1] = last_bit_weights[i]
            gp.weights[:-1].fill_((1-last_bit_weights[i])/(gp.weights.shape[0]-1))
            gp.bit_order = bit_orders[i]
            gp.bit_order_inv_perm = bit_order_to_inv_permutation(gp.bit_order, gp.precision)
            
            mixture_init_bit_orders.append(bit_orders[i].clone())
            mixture_last_bit_weights.append(last_bit_weights[i].clone())
            gp.process()
            print()
            print("Training the weight vector and the bit order:")
            train_time = time.time()
            gp.opt_weights_and_bit_order_bfgs(max_iter=1000, verbose=False)
            mixture_final_bit_orders.append(gp.bit_order.clone())
            train_times.append(time.time() - train_time)
            gp.save(path=f"{name}_seed{seed}_gp{i}___")
            _train_nlls.append(gp.nll)
            predict_time = time.time()
            test_nll = gp.calculate_test_nll(test_y)
            predict_times.append(time.time() - predict_time)
            _test_nlls.append(test_nll)
            test_rmse = gp.rmse(test_y.view(-1))
            _test_rmses.append(test_rmse)
            print(f"Finished restart {i}")
            
            gp_pop.add(gp)
            del gp
            torch.cuda.empty_cache()
            gc.collect()
            gp = ONGP(train_x.to(dtype=torch.float64, device=device),
                  train_y.to(dtype=torch.float64, device=device),
                  test_x.to(dtype=torch.float64, device=device), lambd=LAMBDA, precision="auto")
        del gp
        torch.cuda.empty_cache()
        gc.collect()
        best_idx = torch.argmin(torch.stack(_train_nlls)).item()
        test_nlls.append(_test_nlls[best_idx])
        test_rmses.append(_test_rmses[best_idx])
        for n_gps in (5, 10, 15, 20):
            _gp_pop = GPMixture(train_x.to(device=device, dtype=torch.float64),
              train_y.to(device=device, dtype=torch.float64),
              test_x.to(device=device, dtype=torch.float64),
              lambd=LAMBDA
            )
            for j in range(n_gps):
                _gp_pop.add(gp_pop.gps[j])
            _gp_pop.process_all()
            _gp_pop.get_nlls()
            # compute NLL, RMSE using performance weighting
            test_nll_perf_weighting = _gp_pop.gp_mixture_nll(test_y, weight_func=lambda nlls: torch.exp(-performance_weighting*nlls))
            test_rmse_perf_weighting = _gp_pop.gp_mixture_rmse(test_y, weight_func=lambda nlls: torch.exp(-performance_weighting*nlls))
            # compute NLL RMSE using uniform weighting
            test_nll_uniform_weighting = _gp_pop.gp_mixture_nll(test_y, weight_func=lambda nlls: torch.ones_like(nlls))
            test_rmse_uniform_weighting = _gp_pop.gp_mixture_rmse(test_y, weight_func=lambda nlls: torch.ones_like(nlls))
            mixture_nll_perf_weighting[n_gps] = test_nll_perf_weighting
            mixture_rmse_perf_weighting[n_gps] = test_rmse_perf_weighting
            mixture_nll_uniform_weighting[n_gps] = test_nll_uniform_weighting
            mixture_rmse_uniform_weighting[n_gps] = test_rmse_uniform_weighting
            del _gp_pop
            
        del gp_pop, test_y
        torch.cuda.empty_cache()
        gc.collect()
        mixture_nll_perf_weightings.append(mixture_nll_perf_weighting)
        mixture_rmse_perf_weightings.append(mixture_rmse_perf_weighting)
        mixture_nll_uniform_weightings.append(mixture_nll_uniform_weighting)
        mixture_rmse_uniform_weightings.append(mixture_rmse_uniform_weighting)
    
    test_rmses_all[name] = test_rmses
    test_nlls_all[name] = test_nlls
    train_times_all[name] = train_times
    predict_times_all[name] = predict_times
    init_times_all[name] = init_times
    mixture_rmse_all_perf_weighting[name] = mixture_rmse_perf_weightings
    mixture_nll_all_perf_weighting[name] = mixture_nll_perf_weightings
    mixture_rmse_all_uniform_weighting[name] = mixture_rmse_uniform_weightings
    mixture_nll_all_uniform_weighting[name] = mixture_nll_uniform_weightings
    mixture_nll_all_uniform_weighting[name] = mixture_nll_uniform_weightings
    all_last_bit_weights[name] = mixture_last_bit_weights
    all_init_bit_orders[name] = mixture_init_bit_orders
    all_final_bit_orders[name] = mixture_final_bit_orders
    with open(f"uci_results_mixture_ensemble_{name}_torch_bfgs_160_raw_samps.data", "wb") as f:
        torch.save({
            "test_rmses_all": test_rmses_all, 
            "test_nlls_all": test_nlls_all, 
            "train_times_all": train_times_all, 
            "predict_times_all": predict_times_all,
            "init_times_all": init_times_all,
            "mixture_rmses_all_perf_weighting": mixture_rmse_all_perf_weighting,
            "mixture_nlls_all_perf_weighting": mixture_nll_all_perf_weighting,
            "mixture_rmses_all_uniform_weighting": mixture_rmse_all_uniform_weighting,
            "mixture_nlls_all_uniform_weighting": mixture_nll_all_uniform_weighting,
            "all_last_bit_weights": all_last_bit_weights,
            "all_init_bit_orders": all_init_bit_orders,
            "all_final_bit_orders": all_final_bit_orders,
        }, f)
# Out:
# dataset_path: ../data/uci/pol/pol.mat
# data.shape: torch.Size([15000, 27])
# train_x.shape: torch.Size([9600, 26])
# full kernel size: 0.3 GB
# train_x: min 0.000, max 1.000, mean 0.054, std 0.131
# val_x: min 0.000, max 1.605, mean 0.054, std 0.131
# test_x: min 0.000, max 1.500, mean 0.054, std 0.131
# train_y: min -0.691, max 1.708, mean 0.000, std 1.000
# val_y: min -0.691, max 1.708, mean 0.022, std 1.010
# test_y: min -0.691, max 1.708, mean -0.002, std 0.997
# /home/sdaulton/anaconda3/envs/effgp/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/pol/pol.mat
# data.shape: torch.Size([15000, 27])
# train_x.shape: torch.Size([9600, 26])
# full kernel size: 0.3 GB
# train_x: min 0.000, max 1.000, mean 0.054, std 0.132
# val_x: min 0.000, max 1.605, mean 0.055, std 0.132
# test_x: min 0.000, max 1.412, mean 0.055, std 0.132
# train_y: min -0.695, max 1.704, mean 0.000, std 1.000
# val_y: min -0.695, max 1.704, mean -0.008, std 1.000
# test_y: min -0.695, max 1.704, mean 0.005, std 1.005
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/pol/pol.mat
# data.shape: torch.Size([15000, 27])
# train_x.shape: torch.Size([9600, 26])
# full kernel size: 0.3 GB
# train_x: min 0.000, max 1.000, mean 0.054, std 0.132
# val_x: min 0.000, max 1.605, mean 0.054, std 0.132
# test_x: min 0.000, max 1.359, mean 0.054, std 0.132
# train_y: min -0.693, max 1.703, mean -0.000, std 1.000
# val_y: min -0.693, max 1.703, mean 0.014, std 1.006
# test_y: min -0.693, max 1.703, mean -0.008, std 0.993
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/elevators/elevators.mat
# data.shape: torch.Size([16599, 19])
# train_x.shape: torch.Size([10623, 18])
# full kernel size: 0.4 GB
# train_x: min 0.000, max 1.000, mean 0.536, std 0.252
# val_x: min -0.077, max 1.029, mean 0.536, std 0.253
# test_x: min -0.053, max 1.087, mean 0.534, std 0.252
# train_y: min -2.193, max 5.220, mean 0.000, std 1.000
# val_y: min -2.193, max 5.012, mean -0.043, std 1.003
# test_y: min -2.193, max 4.559, mean 0.015, std 0.999
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/elevators/elevators.mat
# data.shape: torch.Size([16599, 19])
# train_x.shape: torch.Size([10623, 18])
# full kernel size: 0.4 GB
# train_x: min 0.000, max 1.000, mean 0.537, std 0.253
# val_x: min -0.077, max 1.054, mean 0.538, std 0.253
# test_x: min -0.009, max 1.086, mean 0.538, std 0.254
# train_y: min -2.182, max 5.181, mean 0.000, std 1.000
# val_y: min -2.182, max 4.403, mean -0.037, std 0.984
# test_y: min -2.182, max 4.974, mean -0.008, std 0.980
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/elevators/elevators.mat
# data.shape: torch.Size([16599, 19])
# train_x.shape: torch.Size([10623, 18])
# full kernel size: 0.4 GB
# train_x: min 0.000, max 1.000, mean 0.538, std 0.259
# val_x: min -0.083, max 200.000, mean 0.541, std 0.948
# test_x: min -0.148, max 100.000, mean 0.541, std 0.482
# train_y: min -2.202, max 5.252, mean -0.000, std 1.000
# val_y: min -2.202, max 4.705, mean 0.010, std 1.025
# test_y: min -2.202, max 5.042, mean -0.012, std 1.009
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/bike/bike.mat
# data.shape: torch.Size([17379, 18])
# train_x.shape: torch.Size([11122, 17])
# full kernel size: 0.5 GB
# train_x: min 0.000, max 1.000, mean 0.408, std 0.359
# val_x: min 0.000, max 1.000, mean 0.408, std 0.359
# test_x: min 0.000, max 1.015, mean 0.413, std 0.359
# train_y: min -3.033, max 1.573, mean -0.000, std 1.000
# val_y: min -3.033, max 1.567, mean -0.002, std 0.976
# test_y: min -3.033, max 1.573, mean 0.013, std 0.991
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/bike/bike.mat
# data.shape: torch.Size([17379, 18])
# train_x.shape: torch.Size([11122, 17])
# full kernel size: 0.5 GB
# train_x: min 0.000, max 1.000, mean 0.410, std 0.359
# val_x: min 0.000, max 1.000, mean 0.406, std 0.358
# test_x: min 0.000, max 1.015, mean 0.408, std 0.359
# train_y: min -3.055, max 1.580, mean 0.000, std 1.000
# val_y: min -3.055, max 1.575, mean -0.008, std 1.001
# test_y: min -3.055, max 1.581, mean 0.004, std 1.004
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/bike/bike.mat
# data.shape: torch.Size([17379, 18])
# train_x.shape: torch.Size([11122, 17])
# full kernel size: 0.5 GB
# train_x: min 0.000, max 1.000, mean 0.412, std 0.360
# val_x: min 0.000, max 1.082, mean 0.408, std 0.360
# test_x: min 0.000, max 1.066, mean 0.409, std 0.359
# train_y: min -3.077, max 1.579, mean 0.000, std 1.000
# val_y: min -3.077, max 1.574, mean -0.025, std 1.008
# test_y: min -3.077, max 1.553, mean -0.027, std 1.019
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/kin40k/kin40k.mat
# data.shape: torch.Size([40000, 9])
# train_x.shape: torch.Size([25600, 8])
# full kernel size: 2.4 GB
# train_x: min 0.000, max 1.000, mean 0.501, std 0.289
# val_x: min -0.000, max 1.000, mean 0.501, std 0.289
# test_x: min 0.000, max 1.000, mean 0.499, std 0.289
# train_y: min -3.975, max 3.246, mean -0.000, std 1.000
# val_y: min -3.936, max 2.843, mean 0.019, std 1.003
# test_y: min -3.948, max 3.214, mean 0.011, std 1.007
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/kin40k/kin40k.mat
# data.shape: torch.Size([40000, 9])
# train_x.shape: torch.Size([25600, 8])
# full kernel size: 2.4 GB
# train_x: min 0.000, max 1.000, mean 0.500, std 0.289
# val_x: min -0.000, max 1.000, mean 0.502, std 0.290
# test_x: min -0.000, max 1.000, mean 0.500, std 0.288
# train_y: min -3.936, max 3.237, mean 0.000, std 1.000
# val_y: min -3.877, max 3.045, mean 0.007, std 0.997
# test_y: min -3.962, max 3.205, mean 0.025, std 0.996
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/kin40k/kin40k.mat
# data.shape: torch.Size([40000, 9])
# train_x.shape: torch.Size([25600, 8])
# full kernel size: 2.4 GB
# train_x: min 0.000, max 1.000, mean 0.500, std 0.289
# val_x: min -0.000, max 1.000, mean 0.501, std 0.289
# test_x: min -0.000, max 1.000, mean 0.501, std 0.289
# train_y: min -3.973, max 3.152, mean -0.000, std 1.000
# val_y: min -3.947, max 2.737, mean -0.001, std 0.997
# test_y: min -3.900, max 3.240, mean 0.014, std 1.006
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/protein/protein.mat
# data.shape: torch.Size([45730, 10])
# train_x.shape: torch.Size([29267, 9])
# full kernel size: 3.2 GB
# train_x: min 0.000, max 1.000, mean 0.240, std 0.180
# val_x: min -0.010, max 1.005, mean 0.242, std 0.179
# test_x: min -0.010, max 0.984, mean 0.241, std 0.180
# train_y: min -2.432, max 1.551, mean 0.000, std 1.000
# val_y: min -2.432, max 1.551, mean 0.001, std 0.988
# test_y: min -2.432, max 1.550, mean 0.024, std 0.989
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/protein/protein.mat
# data.shape: torch.Size([45730, 10])
# train_x.shape: torch.Size([29267, 9])
# full kernel size: 3.2 GB
# train_x: min 0.000, max 1.000, mean 0.244, std 0.180
# val_x: min -0.010, max 1.058, mean 0.244, std 0.180
# test_x: min -0.002, max 1.058, mean 0.243, std 0.180
# train_y: min -2.452, max 1.558, mean 0.000, std 1.000
# val_y: min -2.452, max 1.558, mean 0.023, std 1.006
# test_y: min -2.452, max 1.557, mean -0.009, std 1.009
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/protein/protein.mat
# data.shape: torch.Size([45730, 10])
# train_x.shape: torch.Size([29267, 9])
# full kernel size: 3.2 GB
# train_x: min 0.000, max 1.000, mean 0.243, std 0.182
# val_x: min -0.010, max 1.017, mean 0.244, std 0.181
# test_x: min -0.011, max 1.063, mean 0.243, std 0.182
# train_y: min -2.452, max 1.549, mean 0.000, std 1.000
# val_y: min -2.452, max 1.549, mean -0.008, std 1.005
# test_y: min -2.452, max 1.549, mean -0.014, std 1.000
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/keggdirected/keggdirected.mat
# data.shape: torch.Size([48827, 21])
# train_x.shape: torch.Size([31248, 20])
# full kernel size: 3.6 GB
# train_x: min 0.000, max 1.000, mean 0.082, std 0.130
# val_x: min 0.000, max 1.654, mean 0.082, std 0.128
# test_x: min -0.008, max 1.000, mean 0.082, std 0.129
# train_y: min -1.733, max 2.889, mean -0.000, std 1.000
# val_y: min -1.733, max 2.923, mean -0.003, std 0.995
# test_y: min -1.733, max 2.874, mean -0.004, std 1.003
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/keggdirected/keggdirected.mat
# data.shape: torch.Size([48827, 21])
# train_x.shape: torch.Size([31248, 20])
# full kernel size: 3.6 GB
# train_x: min 0.000, max 1.000, mean 0.086, std 0.134
# val_x: min 0.000, max 1.185, mean 0.085, std 0.133
# test_x: min -0.008, max 1.237, mean 0.086, std 0.134
# train_y: min -1.727, max 2.917, mean -0.000, std 1.000
# val_y: min -1.727, max 2.778, mean -0.014, std 0.997
# test_y: min -1.727, max 2.884, mean 0.014, std 0.989
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/keggdirected/keggdirected.mat
# data.shape: torch.Size([48827, 21])
# train_x.shape: torch.Size([31248, 20])
# full kernel size: 3.6 GB
# train_x: min 0.000, max 1.000, mean 0.085, std 0.133
# val_x: min 0.000, max 1.000, mean 0.085, std 0.133
# test_x: min 0.000, max 1.100, mean 0.084, std 0.132
# train_y: min -1.735, max 2.925, mean 0.000, std 1.000
# val_y: min -1.735, max 2.840, mean 0.008, std 1.006
# test_y: min -1.735, max 2.892, mean -0.016, std 0.998
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/keggundirected/keggundirected.mat
# data.shape: torch.Size([63608, 28])
# train_x.shape: torch.Size([40708, 27])
# full kernel size: 6.2 GB
# train_x: min 0.000, max 1.000, mean 0.147, std 0.223
# val_x: min 0.000, max 2.014, mean 0.147, std 0.223
# test_x: min 0.000, max 1.161, mean 0.147, std 0.223
# train_y: min -1.709, max 3.791, mean -0.000, std 1.000
# val_y: min -1.709, max 2.720, mean -0.012, std 0.997
# test_y: min -1.709, max 3.000, mean -0.006, std 0.999
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/keggundirected/keggundirected.mat
# data.shape: torch.Size([63608, 28])
# train_x.shape: torch.Size([40708, 27])
# full kernel size: 6.2 GB
# train_x: min 0.000, max 1.000, mean 0.142, std 0.222
# val_x: min 0.000, max 1.000, mean 0.142, std 0.222
# test_x: min -0.007, max 1.148, mean 0.143, std 0.222
# train_y: min -1.703, max 3.794, mean 0.000, std 1.000
# val_y: min -1.703, max 3.794, mean -0.006, std 0.995
# test_y: min -1.703, max 3.510, mean 0.016, std 0.997
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/keggundirected/keggundirected.mat
# data.shape: torch.Size([63608, 28])
# train_x.shape: torch.Size([40708, 27])
# full kernel size: 6.2 GB
# train_x: min 0.000, max 1.000, mean 0.149, std 0.224
# val_x: min -0.021, max 1.410, mean 0.149, std 0.224
# test_x: min -0.008, max 1.963, mean 0.150, std 0.224
# train_y: min -1.710, max 3.801, mean 0.000, std 1.000
# val_y: min -1.710, max 3.801, mean -0.007, std 1.007
# test_y: min -1.710, max 2.594, mean 0.001, std 1.001
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/3droad/3droad.mat
# data.shape: torch.Size([434874, 4])
# train_x.shape: torch.Size([278319, 3])
# full kernel size: 288.6 GB
# train_x: min 0.000, max 1.000, mean 0.519, std 0.245
# val_x: min 0.000, max 1.000, mean 0.519, std 0.245
# test_x: min -0.000, max 1.000, mean 0.520, std 0.245
# train_y: min -1.654, max 5.737, mean -0.000, std 1.000
# val_y: min -1.433, max 6.030, mean 0.002, std 1.001
# test_y: min -1.325, max 5.693, mean -0.001, std 1.000
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/3droad/3droad.mat
# data.shape: torch.Size([434874, 4])
# train_x.shape: torch.Size([278319, 3])
# full kernel size: 288.6 GB
# train_x: min 0.000, max 1.000, mean 0.520, std 0.245
# val_x: min 0.000, max 1.000, mean 0.519, std 0.245
# test_x: min 0.000, max 1.000, mean 0.519, std 0.245
# train_y: min -1.654, max 6.034, mean -0.000, std 1.000
# val_y: min -1.320, max 5.334, mean 0.005, std 1.002
# test_y: min -1.433, max 5.706, mean 0.002, std 1.001
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/3droad/3droad.mat
# data.shape: torch.Size([434874, 4])
# train_x.shape: torch.Size([278319, 3])
# full kernel size: 288.6 GB
# train_x: min 0.000, max 1.000, mean 0.519, std 0.245
# val_x: min -0.000, max 1.000, mean 0.519, std 0.245
# test_x: min 0.000, max 1.000, mean 0.519, std 0.246
# train_y: min -1.653, max 6.023, mean 0.000, std 1.000
# val_y: min -1.273, max 5.856, mean -0.004, std 0.996
# test_y: min -1.361, max 5.697, mean -0.002, std 0.999
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/buzz/buzz.mat
# data.shape: torch.Size([583250, 78])
# train_x.shape: torch.Size([373280, 77])
# full kernel size: 519.1 GB
# train_x: min 0.000, max 1.000, mean 0.173, std 0.373
# val_x: min 0.000, max 2.014, mean 0.173, std 0.373
# test_x: min 0.000, max 2.866, mean 0.173, std 0.373
# train_y: min -1.696, max 3.901, mean -0.000, std 1.000
# val_y: min -1.696, max 3.720, mean 0.000, std 1.003
# test_y: min -1.696, max 3.441, mean -0.003, std 1.003
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/buzz/buzz.mat
# data.shape: torch.Size([583250, 78])
# train_x.shape: torch.Size([373280, 77])
# full kernel size: 519.1 GB
# train_x: min 0.000, max 1.000, mean 0.173, std 0.373
# val_x: min 0.000, max 1.336, mean 0.173, std 0.373
# test_x: min 0.000, max 2.014, mean 0.173, std 0.373
# train_y: min -1.694, max 3.902, mean -0.000, std 1.000
# val_y: min -1.694, max 3.442, mean 0.007, std 1.003
# test_y: min -1.694, max 3.411, mean -0.000, std 1.002
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19
# dataset_path: ../data/uci/buzz/buzz.mat
# data.shape: torch.Size([583250, 78])
# train_x.shape: torch.Size([373280, 77])
# full kernel size: 519.1 GB
# train_x: min 0.000, max 1.000, mean 0.173, std 0.373
# val_x: min 0.000, max 2.349, mean 0.173, std 0.373
# test_x: min 0.000, max 1.500, mean 0.173, std 0.374
# train_y: min -1.694, max 3.898, mean -0.000, std 1.000
# val_y: min -1.694, max 3.717, mean -0.004, std 1.001
# test_y: min -1.694, max 3.438, mean 0.002, std 1.000
#
#
# Training the weight vector and the bit order:
# Finished restart 0
#
# Training the weight vector and the bit order:
# Finished restart 1
#
# Training the weight vector and the bit order:
# Finished restart 2
#
# Training the weight vector and the bit order:
# Finished restart 3
#
# Training the weight vector and the bit order:
# Finished restart 4
#
# Training the weight vector and the bit order:
# Finished restart 5
#
# Training the weight vector and the bit order:
# Finished restart 6
#
# Training the weight vector and the bit order:
# Finished restart 7
#
# Training the weight vector and the bit order:
# Finished restart 8
#
# Training the weight vector and the bit order:
# Finished restart 9
#
# Training the weight vector and the bit order:
# Finished restart 10
#
# Training the weight vector and the bit order:
# Finished restart 11
#
# Training the weight vector and the bit order:
# Finished restart 12
#
# Training the weight vector and the bit order:
# Finished restart 13
#
# Training the weight vector and the bit order:
# Finished restart 14
#
# Training the weight vector and the bit order:
# Finished restart 15
#
# Training the weight vector and the bit order:
# Finished restart 16
#
# Training the weight vector and the bit order:
# Finished restart 17
#
# Training the weight vector and the bit order:
# Finished restart 18
#
# Training the weight vector and the bit order:
# Finished restart 19

# %%
from math import sqrt
for k, v in mixture_rmse_all_perf_weighting.items():
    v = torch.cat([vi[5].view(1) for vi in v])
    m = round(v.mean().item(), 3)
    two_se = round(2*v.std().item()/sqrt(3), 3)
    print(f"{k} & ${m:.3f} \pm {two_se:.3f}$")
# Out:
# pol & $0.154 \pm 0.006$
# elevators & $0.478 \pm 0.021$
# bike & $0.118 \pm 0.057$
# kin40k & $0.580 \pm 0.003$
# protein & $0.608 \pm 0.008$
# keggdirected & $0.086 \pm 0.003$
# keggundirected & $0.120 \pm 0.001$
# 3droad & $0.187 \pm 0.002$
# buzz & $0.801 \pm 0.002$

# %%
from math import sqrt
for k, v in test_rmses_all.items():
    v = torch.cat([vi.view(1) for vi in v])
    m = round(v.mean().item(), 3)
    two_se = round(2*v.std().item()/sqrt(3), 3)
    print(f"{k} & ${m:.3f} \pm {two_se:.3f}$")
# Out:
# pol & $0.161 \pm 0.004$
# elevators & $0.476 \pm 0.018$
# bike & $0.103 \pm 0.029$
# kin40k & $0.587 \pm 0.006$
# protein & $0.623 \pm 0.011$
# keggdirected & $0.086 \pm 0.003$
# keggundirected & $0.121 \pm 0.001$
# 3droad & $0.186 \pm 0.001$
# buzz & $0.801 \pm 0.002$

# %%
from math import sqrt
for k, v in mixture_nll_all_perf_weighting.items():
    v = torch.cat([vi[5].view(1) for vi in v])
    m = round(v.mean().item(), 3)
    two_se = round(2*v.std().item()/sqrt(3), 3)
    print(f"{k} & ${m:.3f} \pm {two_se:.3f}$")
# Out:
# pol & $-0.625 \pm 0.035$
# elevators & $0.649 \pm 0.032$
# bike & $-0.708 \pm 0.433$
# kin40k & $0.869 \pm 0.004$
# protein & $0.781 \pm 0.023$
# keggdirected & $-1.031 \pm 0.020$
# keggundirected & $-0.667 \pm 0.007$
# 3droad & $-0.251 \pm 0.009$
# buzz & $1.198 \pm 0.003$

# %%
from math import sqrt
for k, v in test_nlls_all.items():
    v = torch.cat([vi.view(1) for vi in v])
    m = round(v.mean().item(), 3)
    two_se = round(2*v.std().item()/sqrt(3), 3)
    print(f"{k} & ${m:.3f} \pm {two_se:.3f}$")
# Out:
# pol & $-0.490 \pm 0.040$
# elevators & $0.646 \pm 0.023$
# bike & $-0.806 \pm 0.273$
# kin40k & $0.881 \pm 0.008$
# protein & $0.845 \pm 0.026$
# keggdirected & $-1.029 \pm 0.021$
# keggundirected & $-0.667 \pm 0.007$
# 3droad & $-0.252 \pm 0.006$
# buzz & $1.198 \pm 0.003$

# %%
import numpy as np
name_to_train_time = {}
for name in train_times_all.keys():
    start = 0
    end = NUM_RESTARTS
    train_times = train_times_all[name]
    time_per_seed = []
    while start < len(train_times):
        time_per_seed.append(sum(train_times[start:end]))
        start = end
        end += NUM_RESTARTS
    time_per_seed = np.array(time_per_seed)
    v = time_per_seed
    m = round(v.mean(), 1)
    two_se = round(2*v.std()/sqrt(3), 1)
    print(f"{name} & ${m:.1f} \pm {two_se:.1f}$")
    name_to_train_time[name] = v
# Out:
# pol & $292.3 \pm 34.4$
# elevators & $140.1 \pm 11.4$
# bike & $145.6 \pm 9.3$
# kin40k & $77.7 \pm 1.7$
# protein & $164.5 \pm 11.2$
# keggdirected & $410.1 \pm 23.6$
# keggundirected & $429.1 \pm 32.5$
# 3droad & $101.8 \pm 7.2$
# buzz & $1092.3 \pm 399.6$

# %%
# all times
import numpy as np
for name in init_times_all.keys():
    v = np.array(init_times_all[name]) + name_to_train_time[name]
    m = round(v.mean(), 1)
    two_se = round(2*v.std()/sqrt(3), 1)
    print(f"{name} & ${m:.1f} \pm {two_se:.1f}$")
# Out:
# pol & $309.5 \pm 34.8$
# elevators & $156.0 \pm 11.7$
# bike & $160.6 \pm 9.2$
# kin40k & $86.5 \pm 1.7$
# protein & $175.4 \pm 11.9$
# keggdirected & $428.2 \pm 23.7$
# keggundirected & $447.7 \pm 32.4$
# 3droad & $115.5 \pm 7.2$
# buzz & $1210.5 \pm 399.6$

# %%
import pickle
for name in ("slice", "song"):
    with open(f"name_to_train_time_{name}", "rb") as f:
        name_to_train_time_ = pickle.load(f)
    name_to_train_time.update(name_to_train_time_)

# %%
name_to_train_time
# Out:
# {'pol': array([327.36507845, 274.88425112, 249.43349385]),
#  'elevators': array([121.20926213, 144.21406746, 152.99113321]),
#  'bike': array([134.24829602, 125.98051786, 142.41399646]),
#  'kin40k': array([82.70241547, 81.87185407, 94.50508022]),
#  'protein': array([160.15259004, 168.47843504, 160.73224854]),
#  'keggdirected': array([362.39438057, 354.19152236, 431.59952664]),
#  'keggundirected': array([453.71562719, 416.98658657, 436.41017127]),
#  '3droad': array([ 90.45119095,  87.72546005, 111.81320333]),
#  'buzz': array([ 951.78691745, 1109.7288866 ,  990.30350971]),
#  'slice': array([2865.89637303, 2688.65606141, 3068.13205457]),
#  'song': array([1431.01067042, 1478.47632575, 1526.41949582])}

# %%
import numpy as np
for name in init_times_all.keys():
    v = np.array(init_times_all[name])
    m = round(v.mean(), 1)
    two_se = round(2*v.std()/sqrt(3), 1)
    print(f"{name} & ${m:.1f} \pm {two_se:.1f}$")
# Out:
# pol & $576.8 \pm 29.4$
# elevators & $514.7 \pm 2.7$
# bike & $485.8 \pm 2.3$
# kin40k & $301.2 \pm 30.1$
# protein & $336.2 \pm 19.3$
# keggdirected & $617.2 \pm 25.3$
# keggundirected & $607.9 \pm 4.6$
# 3droad & $432.2 \pm 0.4$
# buzz & $3697.3 \pm 1.2$
